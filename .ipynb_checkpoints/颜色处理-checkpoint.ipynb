# 137964  2.33895e+06  JTXD031460727GA  87938  JTXD03146
# 137965      2338952  JTXD031460728GA  87938  JTXD03146
# 137966      2338953  JTXD031460729GA  87938  JTXD03146
# 137967      2349014    JTXAA6907999F  89584  JTXAA6907
# 137968      2346759  JTXD713030261GA  89169  JTXD71303
# 137969  2.34676e+06  JTXD713030262GA  89169  JTXD71303
# 137970      2346761  JTXD713030263GA  89169  JTXD71303
# 137971      2346762  JTXD713030264GA  89169  JTXD71303
# 137972      2346763  JTXD713030265GA  89169  JTXD71303
# 137973      2346764  JTXD713030266GA  89169  JTXD71303
# 137974      2346765  JTXD713030267GA  89169  JTXD71303
# 137975      2346766  JTXD713030268GA  89169  JTXD71303
# 137976  2.34677e+06  JTXD713030269GA  89169  JTXD71303
#
# [137976 rows x 4 columns]

# %%
def color(row):
    id=row['条码']
    if len(id)>11:
        id=list(id[9:12])
        df.loc[i,'花纹']=id[0]
        df.loc[i,'颜色深度']=id[2]    
        rgb=color_rgb[int(id[1])]
        df.loc[i,'R']=rgb[0]
        df.loc[i,'G']=rgb[1]
        df.loc[i,'B']=rgb[2]

# %%
df['R']=0
df['G']=0
df['B']=0
df['花纹']=0
df['颜色深度']=0
for i in range(len(df)):#转换色彩RGB与颜色深度、花纹
    if i==0:
        continue
    id=df.loc[i,'条码']
    if len(id)<12:
        continue
    id=list(id[9:12])
    df.loc[i,'花纹']=id[0]
    df.loc[i,'颜色深度']=id[2]    
    rgb=color_rgb[int(id[1])]
    df.loc[i,'R']=rgb[0]
    df.loc[i,'G']=rgb[1]
    df.loc[i,'B']=rgb[2]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-6f3dd4eb5f8c> in <module>()
#      11         continue
#      12     id=list(id[9:12])
# ---> 13     df.loc[i,'花纹']=id[0]
#      14     df.loc[i,'颜色深度']=id[2]
#      15     rgb=color_rgb[int(id[1])]
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     192             key = com._apply_if_callable(key, self.obj)
#     193         indexer = self._get_setitem_indexer(key)
# --> 194         self._setitem_with_indexer(indexer, value)
#     195
#     196     def _has_valid_type(self, k, axis):
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     606                 # scalar
#     607                 for item in labels:
# --> 608                     setter(item, value)
#     609
#     610         else:
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     535
#     536                 # reset the sliced object if unique
# --> 537                 self.obj[item] = s
#     538
#     539             def can_do_equal_len():
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2517         else:
#    2518             # set column
# -> 2519             self._set_item(key, value)
#    2520
#    2521     def _setitem_slice(self, key, value):
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2583
#    2584         self._ensure_valid_index(value)
# -> 2585         value = self._sanitize_column(key, value)
#    2586         NDFrame._set_item(self, key, value)
#    2587
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2737
#    2738         if isinstance(value, Series):
# -> 2739             value = reindexer(value)
#    2740
#    2741         elif isinstance(value, DataFrame):
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    2719
#    2720             if value.index.equals(self.index) or not len(self.index):
# -> 2721                 value = value._values.copy()
#    2722             else:
#    2723
#
# KeyboardInterrupt:

# %%
order_data=pd.read_excel('唯衣POC.xlsx',sheet_name=0)
item_id=pd.read_excel('唯衣POC.xlsx',sheet_name=3)

# %%
item_id=item_id.drop(0)
order_data=order_data.drop(0)

# %%
item_id["条码"]=[i[:9] for i in item_id["条码"]]

# %%
order_data=order_data[order_data['订单总金额']>0]

# %%
user_item=pd.merge(order_data,item_id,left_on=['订单所含商品条码ID'],right_on=['条码id'],how='left')

# %%
user_item["buys"]=1
user_item['下订单VIP']=user_item['下订单VIP'].apply(np.round)
user_item.groupby(["下订单VIP","条码"])["buys"].sum().to_csv('alluib_without_color.csv')
user_item[['下订单VIP','条码','buys']]
# Out:
#            下订单VIP         条码  buys
# 0        632551.0  JWVC11116     1
# 1        632551.0  JWVC11116     1
# 2        632551.0  JWVC80302     1
# 3        632551.0  JWVC80302     1
# 4        632551.0  JWVX50043     1
# 5        632551.0  JWVX50043     1
# 6        599626.0  JWVC80302     1
# 7        599626.0  JWVC80302     1
# 8        599626.0  JWVC80302     1
# 9        599626.0  JWVC80302     1
# 10       599626.0  JWVC50015     1
# 11       599626.0  JWVC50015     1
# 12       599626.0  JWVC41209     1
# 13       599626.0  JWVC41209     1
# 14       599626.0  JWVC20206     1
# 15       599626.0  JWVC20206     1
# 16       599626.0  JWUX80303     1
# 17       599626.0  JWUX80303     1
# 18       912664.0  JWWX50068     1
# 19       912664.0  JWWX50068     1
# 20       912664.0  JWWX50074     1
# 21       912664.0  JWWX50074     1
# 22       231808.0  JWWX80335     1
# 23       231808.0  JWWX80335     1
# 24       231808.0  JWWX80375     1
# 25       231808.0  JWWX80375     1
# 26       229386.0  JWWX50068     1
# 27       229386.0  JWWX50068     1
# 28       229386.0  JWWX50074     1
# 29       229386.0  JWWX50074     1
# ...           ...        ...   ...
# 487182  1614003.0  JWXQ31106     1
# 487183  1614003.0  JWXQ31106     1
# 487184  1614003.0  JWXQ31103     1
# 487185  1614003.0  JWXQ31103     1
# 487186  1614003.0  JWXQ31408     1
# 487187  1614003.0  JWXQ31408     1
# 487188  1754164.0  JWXQ50009     1
# 487189  1754164.0  JWXQ50009     1
# 487190  1754164.0  JWXQ60106     1
# 487191  1754164.0  JWXQ60106     1
# 487192   775434.0  JWSC81101     1
# 487193   775434.0  JWSC81101     1
# 487194   775434.0  JWXX80312     1
# 487195   775434.0  JWXX80312     1
# 487196  1754062.0  JWWX80387     1
# 487197  1754062.0  JWWX80387     1
# 487198  1754062.0  JWXQ72202     1
# 487199  1754062.0  JWXQ72202     1
# 487200  1754853.0  JWXQ50015     1
# 487201  1754853.0  JWXQ50015     1
# 487202  1754973.0  JWXQ50027     1
# 487203  1754973.0  JWXQ50027     1
# 487204  1754970.0  JWXQ50018     1
# 487205  1754970.0  JWXQ50018     1
# 487206  1495122.0  JWXQ11101     1
# 487207  1495122.0  JWXQ11101     1
# 487208  1495122.0  JWXQ31007     1
# 487209  1495122.0  JWXQ31007     1
# 487210  1495122.0  JWXQ60106     1
# 487211  1495122.0  JWXQ60106     1
#
# [487212 rows x 3 columns]

# %%
data=pd.read_csv('sample.csv')

# %%
item_info=pd.read_excel('唯衣POC.xlsx',sheet_name=2,header=1)#商品信息表

# %%
id=data['NAME']

# %%
ID=set(id)
len(ID)
# Out:
# 469
