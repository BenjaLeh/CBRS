# %%
import pandas as pd
import numpy as np

# %%
#颜色映射为RGB
color_rgb={1:[255,255,255],2:[0,0,255],3:[160,82,45],4:[160,32,240],5:[255,0,0],6:[255,255,0],7:[192,192,192],8:[0,255,0],9:[233,233,216],0:[0,0,0]}

# %%
df=pd.read_excel('唯衣POC.xlsx',sheet_name=3,header=0)#条码id表
df=df.drop(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1132f0e45480> in <module>()
# ----> 1 df=pd.read_excel('唯衣POC.xlsx',sheet_name=3,header=0)#条码id表
#       2 df=df.drop(0)
#
# D:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# D:\anaconda\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
#     232     return io._parse_excel(
#
# D:\anaconda\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     292             self.book = xlrd.open_workbook(file_contents=data)
#     293         elif isinstance(self._io, compat.string_types):
# --> 294             self.book = xlrd.open_workbook(self._io)
#     295         else:
#     296             raise ValueError('Must explicitly set engine if not passing in'
#
# D:\anaconda\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     141                 formatting_info=formatting_info,
#     142                 on_demand=on_demand,
# --> 143                 ragged_rows=ragged_rows,
#     144                 )
#     145             return bk
#
# D:\anaconda\lib\site-packages\xlrd\xlsx.py in open_workbook_2007_xml(zf, component_names, logfile, verbosity, use_mmap, formatting_info, on_demand, ragged_rows)
#     835         x12sheet = X12Sheet(sheet, logfile, verbosity)
#     836         heading = "Sheet %r (sheetx=%d) from %r" % (sheet.name, sheetx, fname)
# --> 837         x12sheet.process_stream(zflo, heading)
#     838         del zflo
#     839
#
# D:\anaconda\lib\site-packages\xlrd\xlsx.py in own_process_stream(self, stream, heading)
#     544         row_tag = U_SSML12 + "row"
#     545         self_do_row = self.do_row
# --> 546         for event, elem in ET.iterparse(stream):
#     547             if elem.tag == row_tag:
#     548                 self_do_row(elem)
#
# D:\anaconda\lib\xml\etree\ElementTree.py in iterator()
#    1224                 if not data:
#    1225                     break
# -> 1226                 pullparser.feed(data)
#    1227             root = pullparser._close_and_return_root()
#    1228             yield from pullparser.read_events()
#
# D:\anaconda\lib\xml\etree\ElementTree.py in feed(self, data)
#    1266         if data:
#    1267             try:
# -> 1268                 self._parser.feed(data)
#    1269             except SyntaxError as exc:
#    1270                 self._events_queue.append(exc)
#
# KeyboardInterrupt:

# %%
def color(row):
    id=row['条码']
    if len(id)>11:
        id=list(id[9:12])
        row['花纹']=id[0]
        row['颜色深度']=id[2]    
        rgb=color_rgb[int(id[1])]
        row['R']=rgb[0]
        row['G']=rgb[1]
        row['B']=rgb[2]
    return row

# %%
df['R']=0
df['G']=0
df['B']=0
df['花纹']=0
df['颜色深度']=0
df=df.apply(color,axis=1)

# %%
df.to_csv("color_process.csv")

# %% [markdown]
# 下面为订单商品表处理

# %%
order_data=pd.read_excel('唯衣POC.xlsx',sheet_name=0)
item_id=pd.read_excel('唯衣POC.xlsx',sheet_name=3)

# %%
item_id=item_id.drop(0)
order_data=order_data.drop(0)

# %%
item_id["条码"]=[i[:9] for i in item_id["条码"]]

# %%
order_data=order_data[order_data['订单总金额']>0]

# %%
user_item=pd.merge(order_data,item_id,left_on=['订单所含商品条码ID'],right_on=['条码id'],how='left')

# %%
user_item["buys"]=1
user_item['下订单VIP']=user_item['下订单VIP'].apply(np.round)
user_item.groupby(["下订单VIP","条码"])["buys"].sum().to_csv('alluib_without_color.csv')
user_item[['下订单VIP','条码','buys']]
# Out:
#            下订单VIP         条码  buys
# 0        632551.0  JWVC11116     1
# 1        632551.0  JWVC11116     1
# 2        632551.0  JWVC80302     1
# 3        632551.0  JWVC80302     1
# 4        632551.0  JWVX50043     1
# 5        632551.0  JWVX50043     1
# 6        599626.0  JWVC80302     1
# 7        599626.0  JWVC80302     1
# 8        599626.0  JWVC80302     1
# 9        599626.0  JWVC80302     1
# 10       599626.0  JWVC50015     1
# 11       599626.0  JWVC50015     1
# 12       599626.0  JWVC41209     1
# 13       599626.0  JWVC41209     1
# 14       599626.0  JWVC20206     1
# 15       599626.0  JWVC20206     1
# 16       599626.0  JWUX80303     1
# 17       599626.0  JWUX80303     1
# 18       912664.0  JWWX50068     1
# 19       912664.0  JWWX50068     1
# 20       912664.0  JWWX50074     1
# 21       912664.0  JWWX50074     1
# 22       231808.0  JWWX80335     1
# 23       231808.0  JWWX80335     1
# 24       231808.0  JWWX80375     1
# 25       231808.0  JWWX80375     1
# 26       229386.0  JWWX50068     1
# 27       229386.0  JWWX50068     1
# 28       229386.0  JWWX50074     1
# 29       229386.0  JWWX50074     1
# ...           ...        ...   ...
# 487182  1614003.0  JWXQ31106     1
# 487183  1614003.0  JWXQ31106     1
# 487184  1614003.0  JWXQ31103     1
# 487185  1614003.0  JWXQ31103     1
# 487186  1614003.0  JWXQ31408     1
# 487187  1614003.0  JWXQ31408     1
# 487188  1754164.0  JWXQ50009     1
# 487189  1754164.0  JWXQ50009     1
# 487190  1754164.0  JWXQ60106     1
# 487191  1754164.0  JWXQ60106     1
# 487192   775434.0  JWSC81101     1
# 487193   775434.0  JWSC81101     1
# 487194   775434.0  JWXX80312     1
# 487195   775434.0  JWXX80312     1
# 487196  1754062.0  JWWX80387     1
# 487197  1754062.0  JWWX80387     1
# 487198  1754062.0  JWXQ72202     1
# 487199  1754062.0  JWXQ72202     1
# 487200  1754853.0  JWXQ50015     1
# 487201  1754853.0  JWXQ50015     1
# 487202  1754973.0  JWXQ50027     1
# 487203  1754973.0  JWXQ50027     1
# 487204  1754970.0  JWXQ50018     1
# 487205  1754970.0  JWXQ50018     1
# 487206  1495122.0  JWXQ11101     1
# 487207  1495122.0  JWXQ11101     1
# 487208  1495122.0  JWXQ31007     1
# 487209  1495122.0  JWXQ31007     1
# 487210  1495122.0  JWXQ60106     1
# 487211  1495122.0  JWXQ60106     1
#
# [487212 rows x 3 columns]

# %%
data=pd.read_csv('sample.csv')

# %%
item_info=pd.read_excel('唯衣POC.xlsx',sheet_name=2,header=1)#商品信息表

# %%
id=data['NAME']

# %%
ID=set(id)
len(ID)
# Out:
# 469
