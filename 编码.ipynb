# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dataset_1.csv')
print(df.columns)
df=df.drop(['色相','Unnamed: 0'],axis=1)
df
# Out:
# Index(['Unnamed: 0', '客户ID', '衣服单价', '衣服ID', '款式流水号', '颜色深度', '年份', '季节',
#        '小类号码', '颜色式样', '颜色大类', '颜色名称', '品名', '大类', '中类', '品牌定义廓形', '领型', '袖长',
#        '系列', '尺寸组', '标准价', '色相', '色温', '色明度', '色纯度', '对比度', '色调', '廓形', '宽松度',
#        '长度', '款设图-大小复杂度', '款设图-规则性', '款设图-曲直', '材质-垂感', '整体曲直', '量感', '场合',
#        '领型-形状', '领型-曲直', '领型-量感', '裙型裤型'],
#       dtype='object')
#        客户ID  衣服单价             衣服ID  款式流水号  颜色深度     年份  季节  小类号码 颜色式样 颜色大类  \
# 0       483     2  JWWC111010004GB      1     0  2016年  春季   111   素色  黑色系
# 1       483     1  JWWC313012154GA      1     5  2016年  春季   313   条纹  白色系
# 2       483     2  JWXC601021004GA      2     0  2017年  春季   601   花纹  黑色系
# 3       506     4  JWWC310011003GA      1     0  2016年  春季   310   花纹  黑色系
# 4       513     2  JWWX112040006GB      4     0  2016年  夏季   112   素色  黑色系
# 5       513     3  JWXX201031265GB      3     6  2017年  夏季   201   花纹  蓝色系
# 6       513     4  JWXX602011004GA      1     0  2017年  夏季   602   花纹  黑色系
# 7       781     2  JWXC202071006GB      7     0  2017年  春季   202   花纹  黑色系
# 8       781     5  JWXX500140264GA     14     6  2017年  夏季   500   素色  蓝色系
# 9       781     2  JWXX115022205GB      2     0  2017年  夏季   115   条纹  蓝色系
# 10      781     3  JWXX420032203GA      3     0  2017年  夏季   420   条纹  蓝色系
# 11      781     4  JWXX803140005GA     14     0  2017年  夏季   803   素色  黑色系
# 12      971     5  JWXC306040003GA      4     0  2017年  春季   306   素色  黑色系
# 13      971     6  JWXC412010005GA      1     0  2017年  春季   412   素色  黑色系
# 14      971     2  JWXC405011004GA      1     0  2017年  春季   405   花纹  黑色系
# 15      971     2  JWXC405011004GA      1     0  2017年  春季   405   花纹  黑色系
# 16      971     5  JWXC500371004GA     37     0  2017年  春季   500   花纹  黑色系
# 17      971     5  JWXC500040841GA      4     4  2017年  春季   500   素色  绿色系
# 18      971     2  JWXX307020154GA      2     5  2017年  夏季   307   素色  白色系
# 19      984     8  JWWD032051263GA      5     6  2016年  冬季    32   花纹  蓝色系
# 20      984     4  JWXC310051005GA      5     0  2017年  春季   310   花纹  黑色系
# 21      984     3  JWXC311031002GA      3     0  2017年  春季   311   花纹  黑色系
# 22      984     1  JWXX811011155GA      1     5  2017年  夏季   811   花纹  白色系
# 23      984     2  JWXX803331273GA     33     7  2017年  夏季   803   花纹  蓝色系
# 24      984     3  JWXX112030003GB      3     0  2017年  夏季   112   素色  黑色系
# 25      984     5  JWXX500341152GA     34     5  2017年  夏季   500   花纹  白色系
# 26      984     5  JWXX500341152GA     34     5  2017年  夏季   500   花纹  白色系
# 27      984     1  JWXX803161006GA     16     0  2017年  夏季   803   花纹  黑色系
# 28      984     3  JWXX112070656GB      7     5  2017年  夏季   112   素色  黄色系
# 29     1611     6  JWXC315041574GA      4     7  2017年  春季   315   花纹  红色系
# ..      ...   ...              ...    ...   ...    ...  ..   ...  ...  ...
# 969  225596     3  JWXX803151263GA     15     6  2017年  夏季   803   花纹  蓝色系
# 970  226657     3  JWXC500293003GA     29     0  2017年  春季   500   格子  黑色系
# 971  226657     2  JWXC111070572GB      7     7  2017年  春季   111   素色  红色系
# 972  226657     2  JWXQ803011153GA      1     5  2017年  秋季   803   花纹  白色系
# 973  226657     2  JWXX112060005GB      6     0  2017年  夏季   112   素色  黑色系
# 974  226657     2  JWXX312060656GA      6     5  2017年  夏季   312   素色  黄色系
# 975  227549     8  JWXC306010003GA      1     0  2017年  春季   306   素色  黑色系
# 976  227549     2  JWXC313010004GA      1     0  2017年  春季   313   素色  黑色系
# 977  227549     2  JWXC802041002GA      4     0  2017年  春季   802   花纹  黑色系
# 978  227549     2  JWXX111010554GB      1     5  2017年  夏季   111   素色  红色系
# 979  227549     3  JWXX405101004GA     10     0  2017年  夏季   405   花纹  黑色系
# 980  227549     5  JWXX405080802GA      8     0  2017年  夏季   405   素色  绿色系
# 981  227549     5  JWXX307011263GA      1     6  2017年  夏季   307   花纹  蓝色系
# 982  227549     4  JWXX803423004GA     42     0  2017年  夏季   803   格子  黑色系
# 983  227549     8  JWXQ510061574GA      6     7  2017年  秋季   510   花纹  红色系
# 984  227675     2  JWXC111021006GB      2     0  2017年  春季   111   花纹  黑色系
# 985  227675     2  JWXC111081277GB      8     7  2017年  春季   111   花纹  蓝色系
# 986  227675     3  JWXC420010264GA      1     6  2017年  春季   420   素色  蓝色系
# 987  227675     2  JWXC310012156GA      1     5  2017年  春季   310   条纹  白色系
# 988  227675     2  JWXX312072154GA      7     5  2017年  夏季   312   条纹  白色系
# 989  227675     1  JWXX113011003GB      1     0  2017年  夏季   113   花纹  黑色系
# 990  227675     2  JWXX803121003GA     12     0  2017年  夏季   803   花纹  黑色系
# 991  227675     2  JWXX803051006GA      5     0  2017年  夏季   803   花纹  黑色系
# 992  227675     3  JWXC312040006GA      4     0  2017年  春季   312   素色  黑色系
# 993  227720     3  JWWC312041263GA      4     6  2016年  春季   312   花纹  蓝色系
# 994  227720     4  JWWC405111153GA     11     5  2016年  春季   405   花纹  白色系
# 995  227720     1  JWWC313012154GA      1     5  2016年  春季   313   条纹  白色系
# 996  227720     5  JWWC401010002GA      1     0  2016年  春季   401   素色  黑色系
# 997  227720     7  JWXC405031001GA      3     0  2017年  春季   405   花纹  黑色系
# 998  227720     5  JWXC402020003GA      2     0  2017年  春季   402   素色  黑色系
#
#         ...     款设图-规则性 款设图-曲直 材质-垂感 整体曲直   量感   场合 领型-形状 领型-曲直  领型-量感  \
# 0       ...         0.0    0.0    中挺  1.0  3.0   BC   NaN   NaN    NaN
# 1       ...         1.0    1.0    中挺  2.0  3.0    C     圆   5.0    5.0
# 2       ...         0.0    5.0     垂  3.0  3.0   BC     圆   3.0    1.0
# 3       ...         1.0    5.0    中垂  3.0  4.0    C     圆   5.0    3.0
# 4       ...         NaN    NaN    中挺  1.0  2.0    B   NaN   NaN    NaN
# 5       ...         0.0    0.0    中挺  5.0  3.0   BC   NaN   NaN    NaN
# 6       ...         1.0    5.0     垂  3.0  3.0    C     V   1.0    2.0
# 7       ...         0.0    5.0     垂  5.0  3.0    C   NaN   NaN    NaN
# 8       ...         0.0    0.0    中挺  3.0  4.0   BC     圆   5.0    4.0
# 9       ...         1.0    1.0    中挺  2.0  4.0    C   NaN   NaN    NaN
# 10      ...         1.0    1.0    中挺  1.0  3.0  SFB     V   1.0    4.0
# 11      ...         0.0    3.0     垂  5.0  3.0    C     圆   5.0    4.0
# 12      ...         0.0    0.0     垂  2.0  5.0    C   深V领   1.0    5.0
# 13      ...         1.0    5.0    中挺  2.0  4.0    C     圆   5.0    5.0
# 14      ...         0.0    5.0    中垂  4.0  4.0    C     圆   5.0    2.0
# 15      ...         0.0    5.0    中垂  4.0  4.0    C     圆   5.0    2.0
# 16      ...         0.0    3.0     垂  5.0  2.0    C     圆   1.0    3.0
# 17      ...         0.0    0.0     垂  5.0  3.0    C     圆   5.0    4.0
# 18      ...         0.0    0.0     垂  5.0  1.0    C     V   2.0    5.0
# 19      ...         NaN    NaN    中挺  1.0  4.0    C     曲   NaN    4.0
# 20      ...         0.0    4.0    中垂  4.0  5.0    C     曲   5.0    4.0
# 21      ...         0.0    2.0    中垂  4.0  3.0    C     圆   5.0    3.0
# 22      ...         0.0    2.0    中垂  4.0  3.0    C     圆   5.0    4.0
# 23      ...         0.0    1.0     垂  4.0  4.0    C     圆   5.0    4.0
# 24      ...         0.0    0.0     垂  5.0  4.0    C   NaN   NaN    NaN
# 25      ...         0.0    5.0     垂  5.0  4.0    C     圆   5.0    4.0
# 26      ...         0.0    5.0     垂  5.0  4.0    C     圆   5.0    4.0
# 27      ...         0.0    1.0    中垂  4.0  3.0    C     圆   5.0    3.0
# 28      ...         0.0    0.0    中挺  2.0  4.0    S   NaN   NaN    NaN
# 29      ...         0.0    0.0    中挺  5.0  3.0   BC     圆   5.0    3.0
# ..      ...         ...    ...   ...  ...  ...  ...   ...   ...    ...
# 969     ...         0.0    5.0     垂  5.0  3.0    C     圆   5.0    3.0
# 970     ...         0.0    1.0     垂  3.0  3.0   BC     圆   3.0    3.0
# 971     ...         0.0    0.0    中垂  2.0  2.0   BC   NaN   NaN    NaN
# 972     ...         0.0    5.0    中垂  5.0  5.0    C     圆   5.0    4.0
# 973     ...         0.0    0.0     垂  2.0  4.0    C   NaN   NaN    NaN
# 974     ...         1.0    1.0    中垂  4.0  3.0    C     圆   5.0    3.0
# 975     ...         0.0    0.0    中挺  1.0  4.0    C     V   2.0    5.0
# 976     ...         0.0    0.0    中垂  5.0  3.0    C   半高领   2.0    2.0
# 977     ...         0.0    3.0     垂  4.0  4.0    C     圆   5.0    4.0
# 978     ...         0.0    0.0    中挺  3.0  4.0   BC   NaN   NaN    NaN
# 979     ...         0.0    3.0    中挺  2.0  4.0    C     圆   5.0    3.0
# 980     ...         0.0    0.0    中挺  2.0  5.0    C     V   1.0    5.0
# 981     ...         0.0    1.0    中挺  2.0  5.0    C   NaN   NaN    NaN
# 982     ...         1.0    1.0    中垂  3.0  4.0    C     圆   5.0    4.0
# 983     ...         0.0    5.0     垂  5.0  3.0  SFB     圆   5.0    4.0
# 984     ...         0.0    0.0    中挺  2.0  2.0    C   NaN   NaN    NaN
# 985     ...         0.0    1.0    中挺  2.0  2.0    C   NaN   NaN    NaN
# 986     ...         0.0    0.0    中挺  1.0  3.0   BC     V   1.0    3.0
# 987     ...         1.0    1.0    中垂  1.0  4.0    C     曲   5.0    3.0
# 988     ...         1.0    1.0    中垂  2.0  3.0    C     圆   5.0    3.0
# 989     ...         0.0    0.0    中垂  5.0  3.0    C   NaN   NaN    NaN
# 990     ...         0.0    2.0     垂  2.0  4.0    C     V   2.0    3.0
# 991     ...         0.0    3.0    中垂  2.0  4.0    S     圆   5.0    3.0
# 992     ...         0.0    0.0     垂  5.0  3.0    C     圆   5.0    4.0
# 993     ...         1.0    1.0    中垂  2.0  3.0    C     圆   5.0    3.0
# 994     ...         1.0    2.0    中挺  2.0  3.0    C     圆   5.0    4.0
# 995     ...         1.0    1.0    中挺  2.0  3.0    C     圆   5.0    5.0
# 996     ...         0.0    0.0    中挺  2.0  2.0  SFB    深V   1.0    1.0
# 997     ...         0.0    0.0     垂  4.0  4.0    C     圆   5.0    3.0
# 998     ...         0.0    0.0    中挺  2.0  3.0   BC     V   1.0    3.0
#
#            裙型裤型
# 0         铅笔小脚裤
# 1           NaN
# 2           NaN
# 3           NaN
# 4           小脚裤
# 5             H
# 6           NaN
# 7           NaN
# 8           NaN
# 9        A,喇叭短裤
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24        A,直筒裤
# 25          NaN
# 26          NaN
# 27          NaN
# 28   T,略宽松裤，锥形裤
# 29          NaN
# ..          ...
# 969         NaN
# 970         NaN
# 971           T
# 972         NaN
# 973      H,大直筒裤
# 974         NaN
# 975         NaN
# 976         NaN
# 977         NaN
# 978       T,锥形裤
# 979         NaN
# 980         NaN
# 981           H
# 982         NaN
# 983         NaN
# 984     小脚裤、紧身裤
# 985         小脚裤
# 986         NaN
# 987         NaN
# 988         NaN
# 989      O,运动中裤
# 990         NaN
# 991         NaN
# 992         NaN
# 993         NaN
# 994         NaN
# 995         NaN
# 996         NaN
# 997         NaN
# 998         NaN
#
# [999 rows x 39 columns]

# %%
#产生userID集与itemID集
items=df.drop(['客户ID'],axis=1).drop_duplicates(['衣服ID'])#物品特征表
itemsID=items['衣服ID']#物品id表
userID=df['客户ID'].drop_duplicates()#去重

# %%
#需要onehot编码的列名
cols=[  '衣服单价',  '款式流水号', '颜色深度', '年份', '季节',
       '小类号码', '颜色式样', '颜色大类', '颜色名称', '品名', '大类', '中类', '品牌定义廓形', '领型', '袖长',
       '系列', '尺寸组', '标准价', '色相', '色温', '色明度', '色纯度', '对比度', '色调', '廓形', '宽松度',
       '长度', '款设图-大小复杂度', '款设图-规则性', '款设图-曲直', '材质-垂感', '整体曲直', '量感', '场合',
       '领型-形状', '领型-曲直', '领型-量感', '裙型裤型']
items.columns
# Out:
# Index(['衣服ID', '衣服单价', '款式流水号', '颜色深度', '年份', '季节', '小类号码', '颜色式样', '颜色大类',
#        '颜色名称', '品名', '大类', '中类', '品牌定义廓形', '领型', '袖长', '系列', '尺寸组', '标准价',
#        '色温', '色明度', '色纯度', '对比度', '色调', '廓形', '宽松度', '长度', '款设图-大小复杂度',
#        '款设图-规则性', '款设图-曲直', '材质-垂感', '整体曲直', '量感', '场合', '领型-形状', '领型-曲直',
#        '领型-量感', '裙型裤型'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt


def dv_encoder(data):#oneHot编码
    # Importing the dataset
    X=data.iloc[:,:].values#转化为numpy
    
    from sklearn.preprocessing import LabelEncoder, OneHotEncoder
    for i in range(1,15):
        labelencoder_X = LabelEncoder(encoding='utf-8')
        X[:, i] = labelencoder_X.fit_transform(X[:,i])
        
    onehotencoder = OneHotEncoder(categorical_features = list(range(1,10)))
    y = onehotencoder.fit_transform(X).toarray()
    
    return y

# %%
b=items.pop('衣服ID')
items.insert(0,'衣服ID',b)
data=dv_encoder(items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-2f9813c08ab6> in <module>()
#       1 b=items.pop('衣服ID')
#       2 items.insert(0,'衣服ID',b)
# ----> 3 data=dv_encoder(items)
#
# <ipython-input-46-bc62c9936c7f> in dv_encoder(data)
#       8     from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#       9     for i in range(1,15):
# ---> 10         labelencoder_X = LabelEncoder(encoding='utf-8')
#      11         X[:, i] = labelencoder_X.fit_transform(X[:,i])
#      12
#
# TypeError: object() takes no parameters

# %%
dataset = pd.read_csv('Data.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 3].values

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
list(range(14,15))
# Out:
# [14]
